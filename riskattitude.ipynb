# %% [markdown]
# Rough volatility with Python
# Jim Gatheral
#
# For Python Quants, New York, Friday May 6, 2016
#
#
#
# Acknowledgements
# The code in this iPython notebook used to be in R. I am very grateful to Yves Hilpisch and Michael Schwed for translating my R-code to Python.
#
# For slideshow functionality I use RISE by Damián Avila.
#
#
# Outline of presentation
# The time series of historical volatility
#
# Scaling properties
# The RFSV model
#
# Pricing under rough volatility
#
# Forecasting realized variance
#
# The time series of variance swaps
#
# Relating historical and implied
#
# The time series of realized variance
# Assuming an underlying variance process  vs , integrated variance  1δ∫t+δtvsds  may (in principle) be estimated arbitrarily accurately given enough price data.
#
# In practice, market microstructure noise makes estimation harder at very high frequency.
# Sophisticated estimators of integrated variance have been developed to adjust for market microstructure noise. See Gatheral and Oomen [6] (for example) for details of these.
# The Oxford-Man Institute of Quantitative Finance makes historical realized variance (RV) estimates freely available at http://realized.oxford-man.ox.ac.uk. These estimates are updated daily.
#
# Each day, for 21 different indices, all trades and quotes are used to estimate realized (or integrated) variance over the trading day from open to close.
# Using daily RV estimates as proxies for instantaneous variance, we may investigate the time series properties of  vt  empirically.
# First load all necessary Python libraries.

# %%
import warnings; warnings.simplefilter('ignore')
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# from matplotlib.mlab import stineman_interp
import pandas as pd
import pandas_datareader.data as web
import requests
import zipfile as zi 
# import StringIO as sio
from sklearn import datasets, linear_model
import scipy.special as scsp
import statsmodels.api as sm
import math
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
# !pip3 install pandas_datareader

# %%
# url = 'https://realized.oxford-man.ox.ac.uk/images/oxfordmanrealizedvolatilityindices-0.2-final.zip'

# %%
# files1 = zi.ZipFile('./oxfordmanrealizedvolatilityindices.zip', 'r')

# %%
# import os
# files1.extractall(os.getcwd())

# %%
# df = pd.read_csv('./OxfordManRealizedVolatilityIndicess.csv', index_col=0, header=2 )
# df
df = pd.read_csv('./oxfordmanrealizedvolatilityindices.csv', index_col=0, header=0 )
df = df.reset_index()
df = df.rename(columns={'index':'DateID'})
df['DateID']= df['DateID'].apply(lambda x:str.replace(x[0:10],'-',''))
df = df.pivot(index='DateID',columns='Symbol',values=['rk_th2', 'medrv', 'rsv', 'rv5', 'open_to_close',
       'open_price', 'nobs', 'rk_twoscale', 'close_price', 'rsv_ss', 'bv_ss',
       'rk_parzen', 'bv', 'rv10', 'rv10_ss', 'close_time', 'open_time',
       'rv5_ss'])
list_ = [i[1][1:]+'.'+i[0] for i in df.columns]
df.columns = list_
df
# Out:
#           AEX.rk_th2  AORD.rk_th2  BFX.rk_th2  BSESN.rk_th2  BVLG.rk_th2  \
# DateID
# 20000103    0.000102          NaN    0.000180      0.000234          NaN
# 20000104    0.000201     0.000046    0.000365      0.000527          NaN
# 20000105    0.000345     0.000156    0.000327      0.001017          NaN
# 20000106    0.000221     0.000024    0.000266      0.000268          NaN
# 20000107    0.000123     0.000034    0.000135      0.000385          NaN
# ...              ...          ...         ...           ...          ...
# 20220622    0.000174     0.000047    0.000146      0.000055          NaN
# 20220623    0.000156     0.000043    0.000108      0.000089          NaN
# 20220624    0.000091     0.000024    0.000073      0.000068          NaN
# 20220627    0.000212     0.000066    0.000084      0.000043          NaN
# 20220628    0.000100     0.000032    0.000085      0.000039          NaN
#
#           BVSP.rk_th2  DJI.rk_th2  FCHI.rk_th2  FTMIB.rk_th2  FTSE.rk_th2  \
# DateID
# 20000103     0.000300    0.000094     0.000204           NaN          NaN
# 20000104     0.000548    0.000092     0.000315           NaN     0.000209
# 20000105     0.000633    0.000110     0.000313           NaN     0.000149
# 20000106     0.000401    0.000082     0.000238           NaN     0.000132
# 20000107     0.000212    0.000059     0.000251           NaN     0.000148
# ...               ...         ...          ...           ...          ...
# 20220622     0.000079    0.000127     0.000193      0.000075     0.000096
# 20220623     0.000086    0.000126     0.000145      0.000089     0.000051
# 20220624     0.000087    0.000061     0.000090      0.000050     0.000031
# 20220627     0.000051    0.000080     0.000124      0.000054     0.000032
# 20220628     0.000101    0.000091     0.000102      0.000044     0.000041
#
#           ...  OMXHPI.rv5_ss  OMXSPI.rv5_ss  OSEAX.rv5_ss  RUT.rv5_ss  \
# DateID    ...
# 20000103  ...            NaN            NaN           NaN    0.000072
# 20000104  ...            NaN            NaN           NaN    0.000053
# 20000105  ...            NaN            NaN           NaN    0.000060
# 20000106  ...            NaN            NaN           NaN    0.000045
# 20000107  ...            NaN            NaN           NaN    0.000017
# ...       ...            ...            ...           ...         ...
# 20220622  ...       0.000099       0.000147      0.000416    0.000118
# 20220623  ...       0.000174       0.000138      0.000238    0.000140
# 20220624  ...            NaN            NaN      0.000098    0.000111
# 20220627  ...       0.000190       0.000132      0.000203    0.000124
# 20220628  ...       0.000069       0.000106      0.000319    0.000125
#
#           SMSI.rv5_ss  SPX.rv5_ss  SSEC.rv5_ss  SSMI.rv5_ss  STI.rv5_ss  \
# DateID
# 20000103          NaN    0.000141          NaN          NaN    0.000126
# 20000104          NaN    0.000224     0.000117     0.000137    0.000079
# 20000105          NaN    0.000314     0.000206     0.000157    0.001455
# 20000106          NaN    0.000131     0.000254     0.000124    0.000288
# 20000107          NaN    0.000094     0.000514     0.000083    0.000095
# ...               ...         ...          ...          ...         ...
# 20220622     0.000110    0.000149     0.000065     0.000086    0.000055
# 20220623     0.000102    0.000136     0.000057     0.000061    0.000040
# 20220624     0.000079    0.000115     0.000060     0.000056    0.000027
# 20220627     0.000079    0.000121     0.000047     0.000078    0.000023
# 20220628     0.000063    0.000164     0.000046     0.000060    0.000028
#
#           STOXX50E.rv5_ss
# DateID
# 20000103         0.000313
# 20000104         0.000226
# 20000105         0.000464
# 20000106         0.000104
# 20000107         0.000122
# ...                   ...
# 20220622         0.000442
# 20220623         0.000149
# 20220624         0.000102
# 20220627         0.000148
# 20220628         0.000127
#
# [5894 rows x 558 columns]

# %%
[i for i in df.columns.to_list() if 'SPX' in i]
# Out:
# ['SPX.rk_th2',
#  'SPX.medrv',
#  'SPX.rsv',
#  'SPX.rv5',
#  'SPX.open_to_close',
#  'SPX.open_price',
#  'SPX.nobs',
#  'SPX.rk_twoscale',
#  'SPX.close_price',
#  'SPX.rsv_ss',
#  'SPX.bv_ss',
#  'SPX.rk_parzen',
#  'SPX.bv',
#  'SPX.rv10',
#  'SPX.rv10_ss',
#  'SPX.close_time',
#  'SPX.open_time',
#  'SPX.rv5_ss']

# %%
df[[i for i in df.columns.to_list() if 'SPX' in i]]
# Out:
#           SPX.rk_th2  SPX.medrv   SPX.rsv   SPX.rv5  SPX.open_to_close  \
# DateID
# 20000103    0.000130   0.000058  0.000096  0.000141          -0.011602
# 20000104    0.000162   0.000067  0.000180  0.000224          -0.035102
# 20000105    0.000240   0.000142  0.000131  0.000314           0.004625
# 20000106    0.000132   0.000070  0.000056  0.000131           0.002991
# 20000107    0.000095   0.000049  0.000023  0.000094           0.026293
# ...              ...        ...       ...       ...                ...
# 20220622    0.000137   0.000089  0.000066  0.000149           0.006609
# 20220623    0.000150   0.000049  0.000063  0.000136           0.005558
# 20220624    0.000066   0.000029  0.000014  0.000115           0.023762
# 20220627    0.000097   0.000070  0.000063  0.000121          -0.005099
# 20220628    0.000104   0.000087  0.000089  0.000164          -0.023546
#
#           SPX.open_price  SPX.nobs  SPX.rk_twoscale  SPX.close_price  \
# DateID
# 20000103         1471.21    1554.0         0.000122          1454.24
# 20000104         1449.00    1564.0         0.000142          1399.02
# 20000105         1395.62    1552.0         0.000219          1402.09
# 20000106         1398.87    1561.0         0.000127          1403.06
# 20000107         1403.45    1540.0         0.000091          1440.84
# ...                  ...       ...              ...              ...
# 20220622         3733.89   23400.0         0.000143          3758.65
# 20220623         3774.71   23401.0         0.000144          3795.75
# 20220624         3821.75   23400.0         0.000068          3913.65
# 20220627         3920.76   23401.0         0.000097          3900.82
# 20220628         3913.00   23400.0         0.000104          3821.94
#
#           SPX.rsv_ss  SPX.bv_ss  SPX.rk_parzen    SPX.bv  SPX.rv10  \
# DateID
# 20000103    0.000096   0.000141       0.000340  0.000141  0.000164
# 20000104    0.000180   0.000173       0.000215  0.000173  0.000295
# 20000105    0.000131   0.000303       0.000163  0.000303  0.000267
# 20000106    0.000056   0.000128       0.000067  0.000128  0.000115
# 20000107    0.000023   0.000079       0.000215  0.000079  0.000121
# ...              ...        ...            ...       ...       ...
# 20220622    0.000066   0.000138       0.000194  0.000138  0.000149
# 20220623    0.000063   0.000131       0.000085  0.000131  0.000093
# 20220624    0.000014   0.000091       0.000129  0.000091  0.000137
# 20220627    0.000063   0.000118       0.000082  0.000118  0.000095
# 20220628    0.000089   0.000133       0.000191  0.000133  0.000175
#
#           SPX.rv10_ss  SPX.close_time  SPX.open_time  SPX.rv5_ss
# DateID
# 20000103     0.000164        145959.0        83004.0    0.000141
# 20000104     0.000295        150000.0        83009.0    0.000224
# 20000105     0.000267        150003.0        83012.0    0.000314
# 20000106     0.000115        145954.0        83005.0    0.000131
# 20000107     0.000121        150000.0        83000.0    0.000094
# ...               ...             ...            ...         ...
# 20220622     0.000149        160000.0        93001.0    0.000149
# 20220623     0.000093        160001.0        93001.0    0.000136
# 20220624     0.000137        160000.0        93001.0    0.000115
# 20220627     0.000095        160001.0        93001.0    0.000121
# 20220628     0.000175        160000.0        93001.0    0.000164
#
# [5894 rows x 18 columns]

# %%
rv1 = pd.DataFrame(index=df.index)

# %%
for col in df.columns:
    if '.rsv' in col:
        rv1[col] = df[col]
rv1.index = [dt.datetime.strptime(str(date), "%Y%m%d") for date in rv1.index.values]

# %%
# rv1 = rv1[rv1['Symbol']=='.SPX'][['rv5']]
# rv1[rv1.index=='2000-01-03']

# %%
#rv1.columns

# %%
spx = pd.DataFrame(rv1['SPX.rsv'])
spx.plot(color='red', grid=True, title='SPX realized variance',
         figsize=(16, 9), ylim=(0,0.003));

# %%
SPX =pd.read_csv('./SPX.csv',sep='\t')

# %%
SPX['Date'] = pd.to_datetime(SPX['Date'])

# %%
SPX = SPX.drop(columns=['Unnamed: 0'])

# %%
#import matplotlib.pyplot as plt
#plt.plot(SPX['Date'],SPX['Adj Close'])
#plt.figure(figsize=(14, 8), dpi=200)
#plt.show()

# %%
spx['sqrt']= np.sqrt(spx['SPX.rsv'])
spx['log_sqrt'] = np.log(spx['sqrt'])

def del_Raw(q, x): 
    return [np.mean(np.abs(spx['log_sqrt'] - spx['log_sqrt'].shift(lag)) ** q)
            for lag in x]

# %%
plt.figure(figsize=(8, 8))
plt.xlabel('$log(\Delta)$')
plt.ylabel('$log\  m(q.\Delta)$')
plt.ylim=(-3, -.5)

zeta_q = list()
qVec = np.array([.5, 1, 1.5, 2, 3])
x = np.arange(1, 100)
for q in qVec:
    plt.plot(np.log(x), np.log(del_Raw(q, x)), 'o') 
    model = np.polyfit(np.log(x), np.log(del_Raw(q, x)), 1)
    plt.plot(np.log(x), np.log(x) * model[0] + model[1])
    zeta_q.append(model[0])

# %%
plt.figure(figsize=(8,8))
plt.xlabel('q')
plt.ylabel('$\zeta_{q}$')
plt.plot(qVec, zeta_q, 'or')

line = np.polyfit(qVec[:4], zeta_q[:4],1)
plt.plot(qVec, line[0] * qVec + line[1])
h_est= line[0]
print(h_est)
# Out:
# 0.10442252633843498

# %%
def dlsig2(sic, x, pr=False):
    if pr:
        a= np.array([(sig-sig.shift(lag)).dropna() for lag in x])
        a=a ** 2
        print (a.info())
    return [np.mean((sig-sig.shift(lag)).dropna() ** 2) for lag in x]

# %%
# h = list()
# nu = list()
# name_list = list()
# time_list = list()
# for i in range(300,spx.shape[0],10):
#     for col in rv1.columns:
#         try:

#             sig = spx.iloc[i-300:i,[0]][col]
#             print(sig)
#             sig = np.log(np.sqrt(sig))
#             sig = sig.dropna()
#             model = np.polyfit(np.log(x), np.log(dlsig2(sig, x)), 1)
#             nu.append(np.sqrt(np.exp(model[1])))
#             h.append(model[0]/2.)
#             name_list.append(col)
#             time_list.append(spx.iloc[[i],:].index[0])
#         except:
#             pass
    

h = list()
nu = list()

for col in rv1.columns:
    sig = rv1[col]
    sig = np.log(np.sqrt(sig))
    sig = sig.dropna()
    model = np.polyfit(np.log(x), np.log(dlsig2(sig, x)), 1)
    nu.append(np.sqrt(np.exp(model[1])))
    h.append(model[0]/2.)
    
OxfordH = pd.DataFrame({'names':rv1.columns, 'h_est': h, 'nu_est': nu})

# %%
# OxfordH = pd.DataFrame({'names':name_list, 'h_est': h, 'nu_est': nu,'dt':time_list})
# OxfordH
OxfordH
# Out:
#               names     h_est    nu_est
# 0           AEX.rsv       NaN       NaN
# 1          AORD.rsv  0.057554  0.536911
# 2           BFX.rsv  0.106880  0.352962
# 3         BSESN.rsv       NaN       NaN
# 4          BVLG.rsv       NaN       NaN
# ..              ...       ...       ...
# 57       SPX.rsv_ss  0.103988  0.468382
# 58      SSEC.rsv_ss  0.090876  0.433111
# 59      SSMI.rsv_ss  0.126401  0.313327
# 60       STI.rsv_ss       NaN       NaN
# 61  STOXX50E.rsv_ss       NaN       NaN
#
# [62 rows x 3 columns]

# %%
# OxfordH[['h_est','nu_est']].plot()

# %%
from scipy.stats import norm
def plotScaling(j, scaleFactor):
    col_name = rv1.columns[j]
    v = rv1[col_name]
    x = np.arange(1,101)
    
    def xDel(x, lag):
        return x-x.shift(lag)
    
    def sdl(lag):
        return (xDel(np.log(v), lag)).std()
    
    sd1 = (xDel(np.log(v), 1)).std()
    h = OxfordH['h_est'][j]
    f, ax = plt.subplots(2,2,sharex=False, sharey=False, figsize=(10, 10))
    
    for i_0 in range(0, 2):
        for i_1 in range(0, 2):
            la = scaleFactor ** (i_1*1+i_0*2)
        
            hist_val = xDel(np.log(v), la).dropna()
            std = hist_val.std()
            mean = hist_val.mean()
        
            ax[i_0][i_1].set_title('Lag = %s Days' %la)
            n, bins, patches = ax[i_0][i_1].hist(hist_val.values, bins=100,
                                   density=True, facecolor='green',alpha=0.2)
            ax[i_0][i_1].plot(bins, norm.pdf(bins,mean,std), "r")
            ax[i_0][i_1].plot(bins, norm.pdf(bins,0,sd1 * la ** h), "b--")
            hist_val.plot(kind='density', ax=ax[i_0][i_1])

# %%
plotScaling(1,5)

# %%
def c_tilde(h):
    return scsp.gamma(3. / 2. - h) / scsp.gamma(h + 1. / 2.) * scsp.gamma(2. - 2. * h)

def forecast_XTS(rvdata, h, date, nLags, delta, nu):
    i = np.arange(nLags)
    cf = 1./((i + 1. / 2.) ** (h + 1. / 2.) * (i + 1. / 2. + delta))
    ldata = rvdata.truncate(after=date)
    l = len(ldata)
    ldata = np.log(ldata.iloc[l - nLags:])
    ldata['cf'] = np.fliplr([cf])[0]
    # print ldata
    ldata = ldata.dropna()
    fcst = (ldata.iloc[:, 0] * ldata['cf']).sum() / sum(ldata['cf'])
    
    return math.exp(fcst + 2 * nu ** 2 * c_tilde(h) * delta ** (2 * h))

# %%
h = OxfordH[OxfordH['names']=='SPX.rsv']['h_est'].values[0] 
h
# Out:
# 0.10398750046434439

# %%
rvdata = pd.DataFrame(rv1['SPX.rsv'])
nu  = OxfordH[OxfordH['names']=='SPX.rsv']['nu_est'].values[0] # Vol of vol estimate for SPX
h = OxfordH[OxfordH['names']=='SPX.rsv']['h_est'].values[0] 
n = len(rvdata)
delta = 1
nLags = 500
dates = rvdata.iloc[nLags:n-delta].index
rv_predict = [forecast_XTS(rvdata, h=h, date=d, nLags=nLags,
                           delta=delta, nu=nu) for d in dates]
rv_actual = rvdata.iloc[nLags+delta:n].values

# %%
plt.figure(figsize=(8, 8))
plt.plot(rv_predict, rv_actual, 'bo');

# %%
plt.figure(figsize=(11, 6))
vol_actual = np.sqrt(np.multiply(rv_actual,252))
vol_predict = np.sqrt(np.multiply(rv_predict,252))
plt.plot(vol_actual, "b")
plt.plot(vol_predict, "r");

# %%
df_rv_predict = pd.DataFrame({"Dates":dates,"rv_predict":rv_predict})
df_rv_predict
# Out:
#           Dates  rv_predict
# 0    2001-11-26    0.000031
# 1    2001-11-27    0.000069
# 2    2001-11-28    0.000079
# 3    2001-11-29    0.000053
# 4    2001-11-30    0.000041
# ...         ...         ...
# 5388 2022-06-21    0.000118
# 5389 2022-06-22    0.000094
# 5390 2022-06-23    0.000088
# 5391 2022-06-24    0.000041
# 5392 2022-06-27    0.000067
#
# [5393 rows x 2 columns]

# %%
spx = spx.reset_index()

# %%
spx = spx.rename(columns={'index':'Date'})

# %%
df_all = pd.merge(spx,SPX,how='left',on=['Date'])
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close
# 0    2000-01-03  0.000096  0.009805 -4.624887  1455.219971
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971
# ...         ...       ...       ...       ...          ...
# 5889 2022-06-22  0.000066  0.008147 -4.810114  3759.889893
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049
#
# [5894 rows x 5 columns]

# %%
# df_all['SPX.rv5'] = df_all['SPX.rv5']*df_all['SPX.rv5']

# %%
df_all['log_s'] = np.log(df_all['Adj Close'])
df_all['log_v'] = np.log(df_all['SPX.rsv'])
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 0    2000-01-03  0.000096  0.009805 -4.624887  1455.219971  7.282912
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# ...         ...       ...       ...       ...          ...       ...
# 5889 2022-06-22  0.000066  0.008147 -4.810114  3759.889893  8.232145
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v
# 0     -9.249773
# 1     -8.622203
# 2     -8.941470
# 3     -9.795627
# 4    -10.677581
# ...         ...
# 5889  -9.620229
# 5890  -9.667576
# 5891 -11.159295
# 5892  -9.677040
# 5893  -9.328899
#
# [5894 rows x 7 columns]

# %%
df_all['diff_log_s'] = df_all['log_s'].diff()
df_all['diff_log_v'] = df_all['log_v'].diff()
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 0    2000-01-03  0.000096  0.009805 -4.624887  1455.219971  7.282912
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# ...         ...       ...       ...       ...          ...       ...
# 5889 2022-06-22  0.000066  0.008147 -4.810114  3759.889893  8.232145
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v  diff_log_s  diff_log_v
# 0     -9.249773         NaN         NaN
# 1     -8.622203   -0.039099    0.627571
# 2     -8.941470    0.001920   -0.319268
# 3     -9.795627    0.000955   -0.854157
# 4    -10.677581    0.026730   -0.881954
# ...         ...         ...         ...
# 5889  -9.620229   -0.001302         NaN
# 5890  -9.667576    0.009487   -0.047347
# 5891 -11.159295    0.030106   -1.491719
# 5892  -9.677040   -0.002977    1.482255
# 5893  -9.328899   -0.020349    0.348141
#
# [5894 rows x 9 columns]

# %%
df_all['sqrt'] = np.sqrt(df_all['SPX.rsv'])

# %%
df_all['shift_sqrt_v'] = df_all['sqrt'].shift(1)
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 0    2000-01-03  0.000096  0.009805 -4.624887  1455.219971  7.282912
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# ...         ...       ...       ...       ...          ...       ...
# 5889 2022-06-22  0.000066  0.008147 -4.810114  3759.889893  8.232145
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v  diff_log_s  diff_log_v  shift_sqrt_v
# 0     -9.249773         NaN         NaN           NaN
# 1     -8.622203   -0.039099    0.627571      0.009805
# 2     -8.941470    0.001920   -0.319268      0.013419
# 3     -9.795627    0.000955   -0.854157      0.011439
# 4    -10.677581    0.026730   -0.881954      0.007463
# ...         ...         ...         ...           ...
# 5889  -9.620229   -0.001302         NaN           NaN
# 5890  -9.667576    0.009487   -0.047347      0.008147
# 5891 -11.159295    0.030106   -1.491719      0.007956
# 5892  -9.677040   -0.002977    1.482255      0.003774
# 5893  -9.328899   -0.020349    0.348141      0.007919
#
# [5894 rows x 10 columns]

# %%
df_all = df_all.dropna()
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# 5    2000-01-10  0.000034  0.005862 -5.139191  1457.599976  7.284547
# ...         ...       ...       ...       ...          ...       ...
# 5886 2022-06-17  0.000117  0.010820 -4.526353  3674.840088  8.209265
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v  diff_log_s  diff_log_v  shift_sqrt_v
# 1     -8.622203   -0.039099    0.627571      0.009805
# 2     -8.941470    0.001920   -0.319268      0.013419
# 3     -9.795627    0.000955   -0.854157      0.011439
# 4    -10.677581    0.026730   -0.881954      0.007463
# 5    -10.278382    0.011128    0.399200      0.004802
# ...         ...         ...         ...           ...
# 5886  -9.052706    0.002198   -0.488075      0.013811
# 5890  -9.667576    0.009487   -0.047347      0.008147
# 5891 -11.159295    0.030106   -1.491719      0.007956
# 5892  -9.677040   -0.002977    1.482255      0.003774
# 5893  -9.328899   -0.020349    0.348141      0.007919
#
# [5384 rows x 10 columns]

# %%
df_all['diff_log_s_div_sqrt_v'] = df_all['diff_log_s']/df_all['shift_sqrt_v']
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# 5    2000-01-10  0.000034  0.005862 -5.139191  1457.599976  7.284547
# ...         ...       ...       ...       ...          ...       ...
# 5886 2022-06-17  0.000117  0.010820 -4.526353  3674.840088  8.209265
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v  diff_log_s  diff_log_v  shift_sqrt_v  diff_log_s_div_sqrt_v
# 1     -8.622203   -0.039099    0.627571      0.009805              -3.987772
# 2     -8.941470    0.001920   -0.319268      0.013419               0.143108
# 3     -9.795627    0.000955   -0.854157      0.011439               0.083506
# 4    -10.677581    0.026730   -0.881954      0.007463               3.581720
# 5    -10.278382    0.011128    0.399200      0.004802               2.317488
# ...         ...         ...         ...           ...                    ...
# 5886  -9.052706    0.002198   -0.488075      0.013811               0.159185
# 5890  -9.667576    0.009487   -0.047347      0.008147               1.164497
# 5891 -11.159295    0.030106   -1.491719      0.007956               3.783849
# 5892  -9.677040   -0.002977    1.482255      0.003774              -0.788972
# 5893  -9.328899   -0.020349    0.348141      0.007919              -2.569678
#
# [5384 rows x 11 columns]

# %%
corr = np.corrcoef(df_all['diff_log_s_div_sqrt_v'],df_all['diff_log_v'])[0][1]

# %%
h_hat = OxfordH[OxfordH['names']=='SPX.rsv']['h_est'].values[0]

# %%
corr*(h_hat+0.5)/np.sqrt(2*h_hat)
# Out:
# -0.7297722843652522

# %%
OxfordH[OxfordH['names']=='SPX.rsv']
# Out:
#       names     h_est    nu_est
# 26  SPX.rsv  0.103988  0.468382

# %%
df_all['rolling_1m'] = df_all['SPX.rsv'].rolling(30).sum()/30
df_all['rolling_1m_1'] = df_all['SPX.rsv'].rolling(29).sum()/29

# %%
df_all
# Out:
#            Date   SPX.rsv      sqrt  log_sqrt    Adj Close     log_s  \
# 1    2000-01-04  0.000180  0.013419 -4.311101  1399.420044  7.243813
# 2    2000-01-05  0.000131  0.011439 -4.470735  1402.109985  7.245734
# 3    2000-01-06  0.000056  0.007463 -4.897814  1403.449951  7.246689
# 4    2000-01-07  0.000023  0.004802 -5.338791  1441.469971  7.273419
# 5    2000-01-10  0.000034  0.005862 -5.139191  1457.599976  7.284547
# ...         ...       ...       ...       ...          ...       ...
# 5886 2022-06-17  0.000117  0.010820 -4.526353  3674.840088  8.209265
# 5890 2022-06-23  0.000063  0.007956 -4.833788  3795.729980  8.241632
# 5891 2022-06-24  0.000014  0.003774 -5.579647  3911.739990  8.271738
# 5892 2022-06-27  0.000063  0.007919 -4.838520  3900.110107  8.268760
# 5893 2022-06-28  0.000089  0.009424 -4.664450  3821.550049  8.248411
#
#           log_v  diff_log_s  diff_log_v  shift_sqrt_v  diff_log_s_div_sqrt_v  \
# 1     -8.622203   -0.039099    0.627571      0.009805              -3.987772
# 2     -8.941470    0.001920   -0.319268      0.013419               0.143108
# 3     -9.795627    0.000955   -0.854157      0.011439               0.083506
# 4    -10.677581    0.026730   -0.881954      0.007463               3.581720
# 5    -10.278382    0.011128    0.399200      0.004802               2.317488
# ...         ...         ...         ...           ...                    ...
# 5886  -9.052706    0.002198   -0.488075      0.013811               0.159185
# 5890  -9.667576    0.009487   -0.047347      0.008147               1.164497
# 5891 -11.159295    0.030106   -1.491719      0.007956               3.783849
# 5892  -9.677040   -0.002977    1.482255      0.003774              -0.788972
# 5893  -9.328899   -0.020349    0.348141      0.007919              -2.569678
#
#       rolling_1m  rolling_1m_1
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# 5            NaN           NaN
# ...          ...           ...
# 5886    0.000115      0.000111
# 5890    0.000110      0.000107
# 5891    0.000104      0.000101
# 5892    0.000100      0.000097
# 5893    0.000097      0.000094
#
# [5384 rows x 13 columns]

# %%
df_new = pd.read_excel("VARIANCESWAP.xlsx", engine='openpyxl',header=5)
df_new
# Out:
#           Dates  VAR_SWAP_1M_LV  VAR_SWAP_3M_LV  VAR_SWAP_6M_LV  \
# 0    2008-11-04       45.781500       46.273630       43.479500
# 1    2008-11-05       50.383750       49.729380       45.918250
# 2    2008-11-06       60.280560       56.794560       51.461810
# 3    2008-11-07       54.587940       53.353060       48.882630
# 4    2008-11-10       56.355380       54.289690       49.609000
# ...         ...             ...             ...             ...
# 3430 2022-08-01       22.538050       24.473735       26.027563
# 3431 2022-08-02       23.390818       25.028260       26.588154
# 3432 2022-08-03       21.595915       23.744925       25.642710
# 3433 2022-08-04       21.675047       24.107518       25.995660
# 3434 2022-08-05       20.153317       23.604221       25.730418
#
#       VAR_SWAP_12M_LV
# 0           40.999440
# 1           42.647130
# 2           46.078310
# 3           44.214190
# 4           45.247130
# ...               ...
# 3430        27.453327
# 3431        27.749637
# 3432        27.074926
# 3433        27.286304
# 3434        27.185488
#
# [3435 rows x 5 columns]

# %%
for i in ['VAR_SWAP_1M_LV', 'VAR_SWAP_3M_LV', 'VAR_SWAP_6M_LV',
       'VAR_SWAP_12M_LV']:
    
    df_new[i] = df_new[i]/100

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(14,8))
plt.plot(df_new['Dates'], df_new['VAR_SWAP_1M_LV'],label='VAR_SWAP_1M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_3M_LV'],label='VAR_SWAP_3M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_6M_LV'],label='VAR_SWAP_6M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_12M_LV'],label='VAR_SWAP_12M_LV')
plt.legend()
plt.show()

# %%
for i in ['VAR_SWAP_1M_LV', 'VAR_SWAP_3M_LV', 'VAR_SWAP_6M_LV',
       'VAR_SWAP_12M_LV']:
    
    df_new[i] = df_new[i]*df_new[i]

# %%
plt.figure(figsize =(14,8))
plt.plot(df_new['Dates'], df_new['VAR_SWAP_1M_LV'],label='VAR_SWAP_1M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_3M_LV'],label='VAR_SWAP_3M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_6M_LV'],label='VAR_SWAP_6M_LV')
plt.plot(df_new['Dates'], df_new['VAR_SWAP_12M_LV'],label='VAR_SWAP_12M_LV')
plt.legend()
plt.show()

# %%
# list_new = list()
# for i in range(1,len(df_new['VAR_SWAP_1M_LV'].values)):
    
#     list_new.append(df_new['VAR_SWAP_1M_LV'].values[i]*30-df_new['VAR_SWAP_1M_LV'].values[i-1]*29)
# list_new

# %%
list_new_1m = list()
list_dt_1m = list()
for i in range(0,len(df_new['VAR_SWAP_1M_LV'].values)):
    if i<len(df_new['VAR_SWAP_1M_LV'].values)-30:
        list_new_1m.append((df_new['VAR_SWAP_1M_LV'].values[i+30]*31/30-df_new['VAR_SWAP_1M_LV'].values[i]*1/30)/1)
        list_dt_1m.append(df_new['Dates'].values[i+30])
    else:
        pass 
        

df_1m = pd.DataFrame({'Dates':list_dt_1m,'1m':list_new_1m})  
df_1m
# Out:
#           Dates        1m
# 0    2008-12-17  0.232382
# 1    2008-12-18  0.221041
# 2    2008-12-19  0.185797
# 3    2008-12-22  0.196609
# 4    2008-12-23  0.195140
# ...         ...       ...
# 3400 2022-08-01  0.048729
# 3401 2022-08-02  0.053432
# 3402 2022-08-03  0.045260
# 3403 2022-08-04  0.045725
# 3404 2022-08-05  0.039186
#
# [3405 rows x 2 columns]

# %%
list_new_3m = list()
list_dt_3m = list()
for i in range(0,len(df_new['VAR_SWAP_3M_LV'].values)):
    if i<len(df_new['VAR_SWAP_3M_LV'].values)-90:
        list_new_3m.append((df_new['VAR_SWAP_3M_LV'].values[i+90]*91/90-df_new['VAR_SWAP_3M_LV'].values[i]*1/90)/1)
        list_dt_3m.append(df_new['Dates'].values[i+90])
    else:
        pass
        

df_3m = pd.DataFrame({'Dates':list_dt_3m,'3m':list_new_3m})  
df_3m
# Out:
#           Dates        3m
# 0    2009-03-17  0.164634
# 1    2009-03-18  0.161028
# 2    2009-03-19  0.187055
# 3    2009-03-20  0.215517
# 4    2009-03-23  0.193360
# ...         ...       ...
# 3340 2022-08-01  0.059911
# 3341 2022-08-02  0.062657
# 3342 2022-08-03  0.056390
# 3343 2022-08-04  0.058155
# 3344 2022-08-05  0.055745
#
# [3345 rows x 2 columns]

# %%
list_new_6m = list()
list_dt_6m = list()
for i in range(0,len(df_new['VAR_SWAP_6M_LV'].values)):
    if i<len(df_new['VAR_SWAP_6M_LV'].values)-180:
        list_new_6m.append((df_new['VAR_SWAP_6M_LV'].values[i+180]*181/180-df_new['VAR_SWAP_6M_LV'].values[i]*1/180)/1)
        list_dt_6m.append(df_new['Dates'].values[i+180])
    else:
        pass
        

df_6m = pd.DataFrame({'Dates':list_dt_6m,'6m':list_new_6m})  
df_6m
# Out:
#           Dates        6m
# 0    2009-07-24  0.078108
# 1    2009-07-27  0.079487
# 2    2009-07-28  0.084275
# 3    2009-07-29  0.087259
# 4    2009-07-30  0.084946
# ...         ...       ...
# 3250 2022-08-01  0.067824
# 3251 2022-08-02  0.070792
# 3252 2022-08-03  0.065835
# 3253 2022-08-04  0.067664
# 3254 2022-08-05  0.066287
#
# [3255 rows x 2 columns]

# %%
list_new_1Y = list()
list_dt_1Y = list()
for i in range(0,len(df_new['VAR_SWAP_12M_LV'].values)):
    if i<len(df_new['VAR_SWAP_12M_LV'].values)-255:
        list_new_1Y.append((df_new['VAR_SWAP_12M_LV'].values[i+255]*256/255-df_new['VAR_SWAP_12M_LV'].values[i]*1/255)/1)
        list_dt_1Y.append(df_new['Dates'].values[i+255])
    else:
        pass 
        

df_1Y = pd.DataFrame({'Dates':list_dt_1Y,'1Y':list_new_1Y})  
df_1Y
# Out:
#           Dates        1Y
# 0    2009-11-09  0.077283
# 1    2009-11-10  0.078118
# 2    2009-11-11  0.079191
# 3    2009-11-12  0.083814
# 4    2009-11-13  0.082096
# ...         ...       ...
# 3175 2022-08-01  0.075433
# 3176 2022-08-02  0.077081
# 3177 2022-08-03  0.073372
# 3178 2022-08-04  0.074517
# 3179 2022-08-05  0.073962
#
# [3180 rows x 2 columns]

# %%
from functools import reduce
df_vsnm = reduce(lambda x, y: pd.merge(x, y, on='Dates', how='left'), [df_1m, df_3m, df_6m,df_1Y])
df_vsnm
# Out:
#           Dates        1m        3m        6m        1Y
# 0    2008-12-17  0.232382       NaN       NaN       NaN
# 1    2008-12-18  0.221041       NaN       NaN       NaN
# 2    2008-12-19  0.185797       NaN       NaN       NaN
# 3    2008-12-22  0.196609       NaN       NaN       NaN
# 4    2008-12-23  0.195140       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...
# 3400 2022-08-01  0.048729  0.059911  0.067824  0.075433
# 3401 2022-08-02  0.053432  0.062657  0.070792  0.077081
# 3402 2022-08-03  0.045260  0.056390  0.065835  0.073372
# 3403 2022-08-04  0.045725  0.058155  0.067664  0.074517
# 3404 2022-08-05  0.039186  0.055745  0.066287  0.073962
#
# [3405 rows x 5 columns]

# %%
df_vsnm.to_csv("./df_vsnm_nosqrt.csv",sep='\t')

# %%
plt.figure(figsize=(18,8))
plt.plot(df_vsnm['Dates'],df_vsnm['1m'],label='1m')
plt.plot(df_vsnm['Dates'],df_vsnm['3m'],label='3m')
plt.plot(df_vsnm['Dates'],df_vsnm['6m'],label='6m')
plt.plot(df_vsnm['Dates'],df_vsnm['1Y'],label='1Y')
plt.legend()
plt.show()

# %%
# df_vsnm['1m'] = np.sqrt(df_vsnm['1m'])
# df_vsnm['3m'] = np.sqrt(df_vsnm['3m'])
# df_vsnm['6m'] = np.sqrt(df_vsnm['6m'])
# df_vsnm['1Y'] = np.sqrt(df_vsnm['1Y'])

# %%
plt.figure(figsize=(18,8))
plt.plot(df_vsnm['Dates'],df_vsnm['1m'],label='1m')
plt.plot(df_vsnm['Dates'],df_vsnm['3m'],label='3m')
plt.plot(df_vsnm['Dates'],df_vsnm['6m'],label='6m')
plt.plot(df_vsnm['Dates'],df_vsnm['1Y'],label='1Y')
plt.legend()
plt.show()

# %%
def xi(date, tt, nu,h, tscale):  # dt=(u-t) is in units of years
    rvdata = pd.DataFrame(rv1['SPX.rsv'])
    return [ forecast_XTS(rvdata,h=h,date=date,nLags=500,delta=dt*tscale,nu=nu) for dt in tt]

nu = OxfordH[OxfordH['names']=='SPX.rsv']["nu_est"].values[0]
h = OxfordH[OxfordH['names']=='SPX.rsv']['h_est'].values[0]

def varSwapCurve(date, bigT, nSteps, nu, h, tscale, onFactor):
    # Make vector of fwd variances
    tt = [ float(i) * (bigT) / nSteps for i in range(nSteps+1)]
    delta_t = tt[1]
    xicurve = xi(date, tt, nu, h, tscale)
    xicurve_mid = (np.array(xicurve[0:nSteps]) + np.array(xicurve[1:nSteps+1])) / 2
    xicurve_int = np.cumsum(xicurve_mid) * delta_t
    varcurve1 = np.divide(xicurve_int, np.array(tt[1:]))
    varcurve = np.array([xicurve[0],]+list(varcurve1))
    varcurve = varcurve * onFactor * tscale #  onFactor is to compensate for overnight moves
    res = pd.DataFrame({"texp":np.array(tt), "vsQuote":np.sqrt(varcurve)})
    return(res)

# %%
def varSwapForecast(date,tau,nu,h,tscale,onFactor):
    vsc = varSwapCurve(date, bigT=2.5, nSteps=100, nu=nu, h=h,
                      tscale=tscale, onFactor=onFactor) # Creates the whole curve
    x = vsc['texp']
    y = vsc['vsQuote']
#     res = stineman_interp(tau,x,y,None)
    res = np.interp(tau,x,y,None)
  
    return(res)

# Test the function

tau = (.25,.5,1,2)
date = dt.datetime(2010,9,8)
varSwapForecast(date,tau,nu=nu,h=h,tscale=252,onFactor=1)
# Out:
# array([0.12309192, 0.13087859, 0.13961874, 0.14978644])

# %%
df_final = pd.merge(df_vsnm,df_rv_predict,how='left',on=['Dates'])
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict
# 0    2008-12-17  0.232382       NaN       NaN       NaN    0.000377
# 1    2008-12-18  0.221041       NaN       NaN       NaN    0.000374
# 2    2008-12-19  0.185797       NaN       NaN       NaN    0.000293
# 3    2008-12-22  0.196609       NaN       NaN       NaN    0.000253
# 4    2008-12-23  0.195140       NaN       NaN       NaN    0.000232
# ...         ...       ...       ...       ...       ...         ...
# 3400 2022-08-01  0.048729  0.059911  0.067824  0.075345         NaN
# 3401 2022-08-02  0.053432  0.062657  0.070792  0.076985         NaN
# 3402 2022-08-03  0.045260  0.056390  0.065835  0.073273         NaN
# 3403 2022-08-04  0.045725  0.058155  0.067664  0.074432         NaN
# 3404 2022-08-05  0.039186  0.055745  0.066287  0.073895         NaN
#
# [3405 rows x 6 columns]

# %%
df_final = df_final.dropna()
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict
# 335  2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 336  2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 337  2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 338  2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 339  2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3372 2022-06-21  0.088131  0.090867  0.093808  0.090737    0.000118
# 3373 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3374 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3375 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
# 3376 2022-06-27  0.070359  0.076699  0.082780  0.083119    0.000067
#
# [3042 rows x 6 columns]

# %%
# print(np.sqrt(0.16))
# print(np.sqrt(0.000029*255))

# %%
h
# Out:
# 0.10398750046434439

# %%
df_final['rv_predict_30'] = df_final['rv_predict']*30
df_final['rv_predict_255'] = df_final['rv_predict']*255

# %%
# rv_predict_30 = df_final['rv_predict_30'].values[0]
# m1 =  df_final['1m'].values[0]
# df_final['rv_predict_30'] =  df_final['rv_predict_30']/rv_predict_30
# df_final['1m'] =  df_final['1m']/m1

# %%
df_final['log_1m_div_rv_predict'] = np.log(df_final['1m']/df_final['rv_predict_30'])
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict  \
# 335  2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 336  2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 337  2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 338  2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 339  2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3372 2022-06-21  0.088131  0.090867  0.093808  0.090737    0.000118
# 3373 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3374 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3375 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
# 3376 2022-06-27  0.070359  0.076699  0.082780  0.083119    0.000067
#
#       rv_predict_30  log_1m_div_rv_predict     integ    lambda  lambda_integ  \
# 335        0.000871               3.388619  0.001743  0.704748      0.001229
# 336        0.001769               3.340874  0.001744  0.585536      0.001021
# 337        0.001550               3.326327  0.001744  0.529375      0.000923
# 338        0.000799               3.643904  0.001745  0.561640      0.000980
# 339        0.001408               3.486729  0.001745  0.494229      0.000863
# ...             ...                    ...       ...       ...           ...
# 3372       0.003548               3.212437  0.372562  0.090888      0.033861
# 3373       0.002834               3.384441  0.488653  0.123434      0.060316
# 3374       0.002646               3.443053  0.745598  0.128926      0.096127
# 3375       0.001217               4.033303  4.808270  0.246534      0.000000
# 3376       0.002006               3.557401  0.000000  0.000000      0.000000
#
#       sum_lambda_integ  rv_predict_255
# 335           2.847903        0.007401
# 336           2.847903        0.015040
# 337           2.847903        0.013175
# 338           2.847903        0.006793
# 339           2.847903        0.011967
# ...                ...             ...
# 3372          2.847903        0.030158
# 3373          2.847903        0.024086
# 3374          2.847903        0.022490
# 3375          2.847903        0.010343
# 3376          2.847903        0.017052
#
# [3042 rows x 13 columns]

# %%
df_final['log_1Y_div_rv_predict'] = np.log(df_final['1Y']/df_final['rv_predict_255'])
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict  \
# 335  2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 336  2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 337  2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 338  2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 339  2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3372 2022-06-21  0.088131  0.090867  0.093808  0.090737    0.000118
# 3373 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3374 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3375 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
# 3376 2022-06-27  0.070359  0.076699  0.082780  0.083119    0.000067
#
#       rv_predict_30  log_1m_div_rv_predict     integ    lambda  lambda_integ  \
# 335        0.000871               3.388619  0.001743  0.704748      0.001229
# 336        0.001769               3.340874  0.001744  0.585536      0.001021
# 337        0.001550               3.326327  0.001744  0.529375      0.000923
# 338        0.000799               3.643904  0.001745  0.561640      0.000980
# 339        0.001408               3.486729  0.001745  0.494229      0.000863
# ...             ...                    ...       ...       ...           ...
# 3372       0.003548               3.212437  0.372562  0.090888      0.033861
# 3373       0.002834               3.384441  0.488653  0.123434      0.060316
# 3374       0.002646               3.443053  0.745598  0.128926      0.096127
# 3375       0.001217               4.033303  4.808270  0.246534      0.000000
# 3376       0.002006               3.557401  0.000000  0.000000      0.000000
#
#       sum_lambda_integ  rv_predict_255  log_1Y_div_rv_predict
# 335           2.847903        0.007401               2.073782
# 336           2.847903        0.015040               1.489903
# 337           2.847903        0.013175               1.619248
# 338           2.847903        0.006793               2.240207
# 339           2.847903        0.011967               1.808866
# ...                ...             ...                    ...
# 3372          2.847903        0.030158               1.101519
# 3373          2.847903        0.024086               1.307475
# 3374          2.847903        0.022490               1.368841
# 3375          2.847903        0.010343               2.090739
# 3376          2.847903        0.017052               1.584001
#
# [3042 rows x 14 columns]

# %%
# df_final['diff'] = df_final['log_1m_div_rv_predict'].diff()

# %%
# df_final['diff'] = df_final[['log_1m_div_rv_predict','diff']].apply(lambda x:x[0] if pd.isna(x[1]) else x[1],axis=1)

# %%
# df_final

# %%
# df_final['lambda'] = df_final['diff']/1.6556634023571712

# %%
# plt.figure(figsize=(24,8))
# plt.plot(df_final['Dates'],df_final['lambda'],label='lambda')

# plt.legend()
# plt.show()

# %%
import math
from scipy import integrate
h = OxfordH[OxfordH['names']=='SPX.rsv']['h_est'].values[0]
# h = -0.4
def obtain_integ(n,m):
    list_integ = []
    f = lambda x,a : (a-x)**(2*h-1)
    for i in range(n):
        y,err = integrate.quad(f, i, i+1, args=(n,))
        list_integ.append(y)
    list_integ = list_integ + [0 for _ in range(m-n)]
        
    return list_integ

# %%
for i in range(1,df_final.shape[0]):
    if i==1:
        list_integ = obtain_integ(i,df_final.shape[0])
        df_final['integ'] = list_integ
        df_final['lambda'] = 0
        df_final['lambda'] = df_final[['log_1Y_div_rv_predict','integ','lambda']].apply(lambda x: x[0]/x[1] if x[1]>0 else x[2],axis=1)
        df_final
    else:
        list_integ = obtain_integ(i,df_final.shape[0])
        df_final['integ'] = list_integ
        df_final['lambda_integ'] = df_final['lambda']*df_final['integ']
#         df_final['lambda_integ'] = df_final['lambda']*df_final['integ']
        df_final['sum_lambda_integ'] = sum(df_final['lambda_integ'])
        df_final['lambda'] = df_final[['log_1Y_div_rv_predict','integ','lambda','sum_lambda_integ']].apply(lambda x: (x[0]-x[3])/x[1] if x[1]>0 and x[2]==0 else x[2],axis=1)
        df_final

# %%
for i in range(1,df_final.shape[0]):
    if i==1:
        list_integ = obtain_integ(i,df_final.shape[0])
        df_final['integ'] = list_integ
        df_final['lambda'] = 0
        df_final['lambda'] = df_final[['log_1m_div_rv_predict','integ','lambda']].apply(lambda x: x[0]/x[1] if x[1]>0 else x[2],axis=1)
        df_final
    else:
        list_integ = obtain_integ(i,df_final.shape[0])
        df_final['integ'] = list_integ
        df_final['lambda_integ'] = df_final['lambda']*df_final['integ']
#         df_final['lambda_integ'] = df_final['lambda']*df_final['integ']
        df_final['sum_lambda_integ'] = sum(df_final['lambda_integ'])
        df_final['lambda'] = df_final[['log_1m_div_rv_predict','integ','lambda','sum_lambda_integ']].apply(lambda x: (x[0]-x[3])/x[1] if x[1]>0 and x[2]==0 else x[2],axis=1)
        df_final

# %%
# df_final['lambda'].plot()

# %%
plt.figure(figsize=(24,8))
plt.plot(df_final['Dates'],df_final['lambda'],label='$\delta$')

plt.legend()
plt.savefig("./delta.png")
plt.show()

# %%
df_lambda_1m = df_final[['lambda','Dates']]
df_lambda_1m.head()
# Out:
#        lambda      Dates
# 335  0.704748 2010-04-26
# 336  0.585536 2010-04-27
# 337  0.529375 2010-04-28
# 338  0.561640 2010-04-29
# 339  0.494229 2010-04-30

# %%
df_lambda_1Y = df_final[['lambda','Dates']]
df_lambda_1Y.head()
# Out:
#        lambda      Dates
# 335  0.431295 2010-04-26
# 336  0.242983 2010-04-27
# 337  0.255253 2010-04-28
# 338  0.368214 2010-04-29
# 339  0.247000 2010-04-30

# %%
df_lambda = pd.merge(df_lambda_1m,df_lambda_1Y,how='left',on=['Dates'])
df_lambda
# Out:
#       lambda_x      Dates  lambda_y
# 0     0.704748 2010-04-26  0.431295
# 1     0.585536 2010-04-27  0.242983
# 2     0.529375 2010-04-28  0.255253
# 3     0.561640 2010-04-29  0.368214
# 4     0.494229 2010-04-30  0.247000
# ...        ...        ...       ...
# 3037  0.090888 2022-06-21 -0.012023
# 3038  0.123434 2022-06-22  0.027542
# 3039  0.128926 2022-06-23  0.032728
# 3040  0.246534 2022-06-24  0.177378
# 3041  0.000000 2022-06-27  0.000000
#
# [3042 rows x 3 columns]

# %%
plt.figure(figsize=(24,8))
plt.plot(df_lambda['Dates'],df_lambda['lambda_x'],label='$\lambda_1m$')
plt.plot(df_lambda['Dates'],df_lambda['lambda_y'],label='$\lambda_1Y$')
plt.legend()
# plt.savefig("./delta.png")
plt.show()

# %%
df_final['lambda'].mean()
# Out:
# 0.10026746929419843

# %%
df_final['lambda'].describe()
# Out:
# count    3042.000000
# mean        0.100267
# std         0.103938
# min        -0.345785
# 25%         0.036800
# 50%         0.106191
# 75%         0.172242
# max         0.531951
# Name: lambda, dtype: float64

# %%
df_final[df_final['lambda']>0]
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict  \
# 335  2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 336  2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 337  2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 338  2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 339  2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3363 2022-06-07  0.055431  0.066264  0.074922  0.078488    0.000045
# 3364 2022-06-08  0.056415  0.067458  0.075977  0.077343    0.000064
# 3373 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3374 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3375 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
#
#       rv_predict_30  log_1m_div_rv_predict     integ    lambda  lambda_integ  \
# 335        0.000871               3.388619  0.001743  0.431295      0.000752
# 336        0.001769               3.340874  0.001744  0.242983      0.000424
# 337        0.001550               3.326327  0.001744  0.255253      0.000445
# 338        0.000799               3.643904  0.001745  0.368214      0.000642
# 339        0.001408               3.486729  0.001745  0.247000      0.000431
# ...             ...                    ...       ...       ...           ...
# 3363       0.001343               3.720580  0.135327  0.125034      0.016921
# 3364       0.001914               3.383365  0.144576  0.031973      0.004622
# 3373       0.002834               3.384441  0.488653  0.027542      0.013458
# 3374       0.002646               3.443053  0.745598  0.032728      0.024402
# 3375       0.001217               4.033303  4.808270  0.177378      0.000000
#
#       sum_lambda_integ  rv_predict_255  log_1Y_div_rv_predict
# 335           1.237858        0.007401               2.073782
# 336           1.237858        0.015040               1.489903
# 337           1.237858        0.013175               1.619248
# 338           1.237858        0.006793               2.240207
# 339           1.237858        0.011967               1.808866
# ...                ...             ...                    ...
# 3363          1.237858        0.011412               1.928309
# 3364          1.237858        0.016272               1.558823
# 3373          1.237858        0.024086               1.307475
# 3374          1.237858        0.022490               1.368841
# 3375          1.237858        0.010343               2.090739
#
# [2532 rows x 14 columns]

# %%
df_final[df_final['lambda']>0].shape[0]/df_final.shape[0]
# Out:
# 0.8323471400394478

# %%
df_final.shape[0]*0.8
# Out:
# 2433.6

# %%
import numpy as np
import matplotlib.pyplot as plt
from hurst import compute_Hc, random_walk

# Use random_walk() function or generate a random walk series manually:
# series = random_walk(99999, cumprod=True)
np.random.seed(42)
random_changes = 1. + np.random.randn(99999) / 1000.
series = df_final_tmp['lambda'] # np.cumprod(random_changes)  # create a random walk from random changes

# Evaluate Hurst equation
H, c, data = compute_Hc(series, kind='price', simplified=True)

# Plot
f, ax = plt.subplots()
ax.plot(data[0], c*data[0]**H, color="deepskyblue")
ax.scatter(data[0], data[1], color="purple")
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time interval')
ax.set_ylabel('R/S ratio')
ax.grid(True)
plt.show()

print("H={:.4f}, c={:.4f}".format(H,c))
# Out:
# H=0.5830, c=0.8759

# %%
df_final_tmp = df_final[df_final['lambda']>0]
df_final_tmp['lambda'] = np.sqrt(df_final_tmp['lambda'])

# %%
aaa = np.arange(0,10,0.01)
ab = [x**0.2 for x in aaa]
plt.plot(ab)
plt.show()

# %%
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict  \
# 335  2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 336  2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 337  2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 338  2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 339  2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3372 2022-06-21  0.088131  0.090867  0.093808  0.090737    0.000118
# 3373 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3374 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3375 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
# 3376 2022-06-27  0.070359  0.076699  0.082780  0.083119    0.000067
#
#       rv_predict_30  log_1m_div_rv_predict     integ    lambda  lambda_integ  \
# 335        0.000871               3.388619  0.001743  0.704748      0.001229
# 336        0.001769               3.340874  0.001744  0.585536      0.001021
# 337        0.001550               3.326327  0.001744  0.529375      0.000923
# 338        0.000799               3.643904  0.001745  0.561640      0.000980
# 339        0.001408               3.486729  0.001745  0.494229      0.000863
# ...             ...                    ...       ...       ...           ...
# 3372       0.003548               3.212437  0.372562  0.090888      0.033861
# 3373       0.002834               3.384441  0.488653  0.123434      0.060316
# 3374       0.002646               3.443053  0.745598  0.128926      0.096127
# 3375       0.001217               4.033303  4.808270  0.246534      0.000000
# 3376       0.002006               3.557401  0.000000  0.000000      0.000000
#
#       sum_lambda_integ  rv_predict_255  log_1Y_div_rv_predict
# 335           2.847903        0.007401               2.073782
# 336           2.847903        0.015040               1.489903
# 337           2.847903        0.013175               1.619248
# 338           2.847903        0.006793               2.240207
# 339           2.847903        0.011967               1.808866
# ...                ...             ...                    ...
# 3372          2.847903        0.030158               1.101519
# 3373          2.847903        0.024086               1.307475
# 3374          2.847903        0.022490               1.368841
# 3375          2.847903        0.010343               2.090739
# 3376          2.847903        0.017052               1.584001
#
# [3042 rows x 14 columns]

# %%
log_1Y_div_rv_predict_0 = df_final['log_1Y_div_rv_predict'].values[0]
VAR_SWAP_12M_LV = df_final['VAR_SWAP_12M_LV'].values[0]
df_final['exp_log_1Y_div_rv_predict'] = np.exp(df_final['log_1Y_div_rv_predict'])*VAR_SWAP_12M_LV/log_1Y_div_rv_predict_0

# %%
df_final['1y_div_rv_predict_255'] = (df_final['VAR_SWAP_12M_LV']-df_final['rv_predict_255'])*10

# %%
df_final[['exp_log_1Y_div_rv_predict','1y_div_rv_predict_255']].plot()
# Out:
# <AxesSubplot:>

# %%
df_new
# Out:
#           Dates  VAR_SWAP_1M_LV  VAR_SWAP_3M_LV  VAR_SWAP_6M_LV  \
# 0    2008-11-04        0.209595        0.214125        0.189047
# 1    2008-11-05        0.253852        0.247301        0.210849
# 2    2008-11-06        0.363375        0.322562        0.264832
# 3    2008-11-07        0.297984        0.284655        0.238951
# 4    2008-11-10        0.317593        0.294737        0.246105
# ...         ...             ...             ...             ...
# 3430 2022-08-01        0.050796        0.059896        0.067743
# 3431 2022-08-02        0.054713        0.062641        0.070693
# 3432 2022-08-03        0.046638        0.056382        0.065755
# 3433 2022-08-04        0.046981        0.058117        0.067577
# 3434 2022-08-05        0.040616        0.055716        0.066205
#
#       VAR_SWAP_12M_LV
# 0            0.168095
# 1            0.181878
# 2            0.212321
# 3            0.195489
# 4            0.204730
# ...               ...
# 3430         0.075369
# 3431         0.077004
# 3432         0.073305
# 3433         0.074454
# 3434         0.073905
#
# [3435 rows x 5 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3435 entries, 0 to 3434
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Dates            3435 non-null   datetime64[ns]
#  1   VAR_SWAP_1M_LV   3435 non-null   float64
#  2   VAR_SWAP_3M_LV   3435 non-null   float64
#  3   VAR_SWAP_6M_LV   3435 non-null   float64
#  4   VAR_SWAP_12M_LV  3435 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 134.3 KB

# %%
df_final = pd.merge(df_final,df_new[['Dates','VAR_SWAP_12M_LV']],how='left',on=['Dates'])
df_final
# Out:
#           Dates        1m        3m        6m        1Y  rv_predict  \
# 0    2010-04-26  0.025794  0.037691  0.049187  0.058872    0.000029
# 1    2010-04-27  0.049976  0.050865  0.058690  0.066728    0.000059
# 2    2010-04-28  0.043147  0.049853  0.059002  0.066526    0.000052
# 3    2010-04-29  0.030560  0.043785  0.053994  0.063820    0.000027
# 4    2010-04-30  0.046007  0.055025  0.064389  0.073040    0.000047
# ...         ...       ...       ...       ...       ...         ...
# 3037 2022-06-21  0.088131  0.090867  0.093808  0.090737    0.000118
# 3038 2022-06-22  0.083598  0.087692  0.091639  0.089044    0.000094
# 3039 2022-06-23  0.082771  0.086343  0.090704  0.088405    0.000088
# 3040 2022-06-24  0.068686  0.078945  0.084229  0.083684    0.000041
# 3041 2022-06-27  0.070359  0.076699  0.082780  0.083119    0.000067
#
#       rv_predict_30  log_1m_div_rv_predict     integ    lambda  lambda_integ  \
# 0          0.000871               3.388619  0.001743  0.431295      0.000752
# 1          0.001769               3.340874  0.001744  0.242983      0.000424
# 2          0.001550               3.326327  0.001744  0.255253      0.000445
# 3          0.000799               3.643904  0.001745  0.368214      0.000642
# 4          0.001408               3.486729  0.001745  0.247000      0.000431
# ...             ...                    ...       ...       ...           ...
# 3037       0.003548               3.212437  0.372562 -0.012023     -0.004479
# 3038       0.002834               3.384441  0.488653  0.027542      0.013458
# 3039       0.002646               3.443053  0.745598  0.032728      0.024402
# 3040       0.001217               4.033303  4.808270  0.177378      0.000000
# 3041       0.002006               3.557401  0.000000  0.000000      0.000000
#
#       sum_lambda_integ  rv_predict_255  log_1Y_div_rv_predict  \
# 0             1.237858        0.007401               2.073782
# 1             1.237858        0.015040               1.489903
# 2             1.237858        0.013175               1.619248
# 3             1.237858        0.006793               2.240207
# 4             1.237858        0.011967               1.808866
# ...                ...             ...                    ...
# 3037          1.237858        0.030158               1.101519
# 3038          1.237858        0.024086               1.307475
# 3039          1.237858        0.022490               1.368841
# 3040          1.237858        0.010343               2.090739
# 3041          1.237858        0.017052               1.584001
#
#       exp_log_1Y_div_rv_predict  1y_div_rv_predict_255  VAR_SWAP_12M_LV
# 0                      0.225829               0.514714         0.059171
# 1                      0.125951               0.516880         0.067043
# 2                      0.143343               0.533505         0.066924
# 3                      0.266720               0.570276         0.064180
# 4                      0.173272               0.610731         0.073400
# ...                         ...                    ...              ...
# 3037                   0.085414               0.605794         0.090672
# 3038                   0.104948               0.649571         0.088980
# 3039                   0.111590               0.659148         0.088363
# 3040                   0.229690               0.733406         0.083646
# 3041                   0.138379               0.660673         0.083080
#
# [3042 rows x 17 columns]

# %%
np.sqrt(0.000087)
